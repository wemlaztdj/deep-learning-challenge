# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# WARNING:tensorflow:From e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   EIN                     34299 non-null  int64
#  1   NAME                    34299 non-null  object
#  2   APPLICATION_TYPE        34299 non-null  object
#  3   AFFILIATION             34299 non-null  object
#  4   CLASSIFICATION          34299 non-null  object
#  5   USE_CASE                34299 non-null  object
#  6   ORGANIZATION            34299 non-null  object
#  7   STATUS                  34299 non-null  int64
#  8   INCOME_AMT              34299 non-null  object
#  9   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  10  ASK_AMT                 34299 non-null  int64
#  11  IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 3.1+ MB

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df=application_df.drop(columns=['EIN','NAME'])

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_value_counts=application_df['APPLICATION_TYPE'].value_counts()
app_value_counts[app_value_counts < 200]
# Out:
# T9     156
# T13     66
# T12     27
# T2      16
# T25      3
# T14      3
# T29      2
# T15      2
# T17      1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace=app_value_counts[app_value_counts < 200].index.tolist()


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_value_counts=application_df['CLASSIFICATION'].value_counts()
class_value_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_value_counts[class_value_counts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace=class_value_counts[class_value_counts < 1000].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
X=pd.get_dummies(application_df)
X
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y=X['IS_SUCCESSFUL']
X = X.drop(columns=['IS_SUCCESSFUL'])



# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train
# Out:
#        STATUS  ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 10679       1     5000                       0                     0
# 5052        1     5000                       0                     0
# 9990        1     5000                       0                     0
# 25173       1     5000                       0                     0
# 11405       1     5000                       0                     1
# ...       ...      ...                     ...                   ...
# 7813        1     5000                       0                     0
# 32511       1     5000                       0                     0
# 5192        1     5000                       0                     0
# 12172       1     5000                       0                     0
# 33003       1     5000                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 10679                     0                    1                    0
# 5052                      0                    0                    0
# 9990                      0                    1                    0
# 25173                     0                    1                    0
# 11405                     0                    0                    0
# ...                     ...                  ...                  ...
# 7813                      0                    1                    0
# 32511                     0                    0                    0
# 5192                      0                    1                    0
# 12172                     0                    1                    0
# 33003                     0                    0                    1
#
#        APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  APPLICATION_TYPE_T7  ...  \
# 10679                    0                    0                    0  ...
# 5052                     0                    1                    0  ...
# 9990                     0                    0                    0  ...
# 25173                    0                    0                    0  ...
# 11405                    0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 7813                     0                    0                    0  ...
# 32511                    1                    0                    0  ...
# 5192                     0                    0                    0  ...
# 12172                    0                    0                    0  ...
# 33003                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 10679                  0                       0                         0
# 5052                   0                       0                         0
# 9990                   0                       0                         0
# 25173                  0                       0                         0
# 11405                  0                       0                         0
# ...                  ...                     ...                       ...
# 7813                   0                       0                         0
# 32511                  0                       0                         0
# 5192                   0                       0                         0
# 12172                  0                       0                         0
# 33003                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 10679                   0                 0                       0
# 5052                    0                 0                       0
# 9990                    0                 0                       0
# 25173                   0                 0                       0
# 11405                   0                 0                       0
# ...                   ...               ...                     ...
# 7813                    0                 0                       0
# 32511                   0                 0                       0
# 5192                    0                 0                       0
# 12172                   0                 0                       0
# 33003                   0                 0                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 10679                0                  0                         1
# 5052                 0                  0                         1
# 9990                 0                  0                         1
# 25173                0                  0                         1
# 11405                0                  0                         1
# ...                ...                ...                       ...
# 7813                 0                  0                         1
# 32511                0                  0                         1
# 5192                 0                  0                         1
# 12172                0                  0                         1
# 33003                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 10679                         0
# 5052                          0
# 9990                          0
# 25173                         0
# 11405                         0
# ...                         ...
# 7813                          0
# 32511                         0
# 5192                          0
# 12172                         0
# 33003                         0
#
# [25724 rows x 43 columns]

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = 43
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
# Output layer

nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
nn.summary()
# Out:
# WARNING:tensorflow:From e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 50)                4050
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 7621 (29.77 KB)
# Trainable params: 7621 (29.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 804/804 [==============================] - 1s 811us/step - loss: 0.5715 - accuracy: 0.7210
# Epoch 2/200
# 804/804 [==============================] - 1s 786us/step - loss: 0.5565 - accuracy: 0.7279
# Epoch 3/200
# 804/804 [==============================] - 1s 796us/step - loss: 0.5540 - accuracy: 0.7296
# Epoch 4/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5512 - accuracy: 0.7303
# Epoch 5/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5500 - accuracy: 0.7309
# Epoch 6/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5486 - accuracy: 0.7318
# Epoch 7/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5482 - accuracy: 0.7322
# Epoch 8/200
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7338
# Epoch 9/200
# 804/804 [==============================] - 1s 827us/step - loss: 0.5462 - accuracy: 0.7332
# Epoch 10/200
# 804/804 [==============================] - 1s 799us/step - loss: 0.5466 - accuracy: 0.7334
# Epoch 11/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5457 - accuracy: 0.7345
# Epoch 12/200
# 804/804 [==============================] - 1s 791us/step - loss: 0.5457 - accuracy: 0.7332
# Epoch 13/200
# 804/804 [==============================] - 1s 791us/step - loss: 0.5451 - accuracy: 0.7342
# Epoch 14/200
# 804/804 [==============================] - 1s 818us/step - loss: 0.5445 - accuracy: 0.7336
# Epoch 15/200
# 804/804 [==============================] - 1s 810us/step - loss: 0.5439 - accuracy: 0.7349
# Epoch 16/200
# 804/804 [==============================] - 1s 791us/step - loss: 0.5439 - accuracy: 0.7352
# Epoch 17/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5433 - accuracy: 0.7348
# Epoch 18/200
# 804/804 [==============================] - 1s 822us/step - loss: 0.5428 - accuracy: 0.7362
# Epoch 19/200
# 804/804 [==============================] - 1s 821us/step - loss: 0.5434 - accuracy: 0.7355
# Epoch 20/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5423 - accuracy: 0.7366
# Epoch 21/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5423 - accuracy: 0.7352
# Epoch 22/200
# 804/804 [==============================] - 1s 774us/step - loss: 0.5425 - accuracy: 0.7358
# Epoch 23/200
# 804/804 [==============================] - 1s 784us/step - loss: 0.5419 - accuracy: 0.7371
# Epoch 24/200
# 804/804 [==============================] - 1s 765us/step - loss: 0.5413 - accuracy: 0.7378
# Epoch 25/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5416 - accuracy: 0.7364
# Epoch 26/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5412 - accuracy: 0.7366
# Epoch 27/200
# 804/804 [==============================] - 1s 771us/step - loss: 0.5410 - accuracy: 0.7372
# Epoch 28/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5407 - accuracy: 0.7371
# Epoch 29/200
# 804/804 [==============================] - 1s 802us/step - loss: 0.5410 - accuracy: 0.7372
# Epoch 30/200
# 804/804 [==============================] - 1s 790us/step - loss: 0.5397 - accuracy: 0.7372
# Epoch 31/200
# 804/804 [==============================] - 1s 800us/step - loss: 0.5404 - accuracy: 0.7377
# Epoch 32/200
# 804/804 [==============================] - 1s 796us/step - loss: 0.5404 - accuracy: 0.7365
# Epoch 33/200
# 804/804 [==============================] - 1s 803us/step - loss: 0.5398 - accuracy: 0.7381
# Epoch 34/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5398 - accuracy: 0.7369
# Epoch 35/200
# 804/804 [==============================] - 1s 792us/step - loss: 0.5395 - accuracy: 0.7376
# Epoch 36/200
# 804/804 [==============================] - 1s 796us/step - loss: 0.5398 - accuracy: 0.7377
# Epoch 37/200
# 804/804 [==============================] - 1s 791us/step - loss: 0.5394 - accuracy: 0.7378
# Epoch 38/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5394 - accuracy: 0.7372
# Epoch 39/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5388 - accuracy: 0.7366
# Epoch 40/200
# 804/804 [==============================] - 1s 827us/step - loss: 0.5393 - accuracy: 0.7369
# Epoch 41/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5388 - accuracy: 0.7375
# Epoch 42/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5389 - accuracy: 0.7375
# Epoch 43/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5383 - accuracy: 0.7372
# Epoch 44/200
# 804/804 [==============================] - 1s 805us/step - loss: 0.5383 - accuracy: 0.7383
# Epoch 45/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5384 - accuracy: 0.7381
# Epoch 46/200
# 804/804 [==============================] - 1s 791us/step - loss: 0.5383 - accuracy: 0.7385
# Epoch 47/200
# 804/804 [==============================] - 1s 798us/step - loss: 0.5380 - accuracy: 0.7385
# Epoch 48/200
# 804/804 [==============================] - 1s 790us/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 49/200
# 804/804 [==============================] - 1s 794us/step - loss: 0.5378 - accuracy: 0.7368
# Epoch 50/200
# 804/804 [==============================] - 1s 796us/step - loss: 0.5375 - accuracy: 0.7383
# Epoch 51/200
# 804/804 [==============================] - 1s 787us/step - loss: 0.5377 - accuracy: 0.7394
# Epoch 52/200
# 804/804 [==============================] - 1s 814us/step - loss: 0.5376 - accuracy: 0.7385
# Epoch 53/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5373 - accuracy: 0.7387
# Epoch 54/200
# 804/804 [==============================] - 1s 796us/step - loss: 0.5372 - accuracy: 0.7388
# Epoch 55/200
# 804/804 [==============================] - 1s 810us/step - loss: 0.5370 - accuracy: 0.7396
# Epoch 56/200
# 804/804 [==============================] - 1s 825us/step - loss: 0.5370 - accuracy: 0.7393
# Epoch 57/200
# 804/804 [==============================] - 1s 790us/step - loss: 0.5372 - accuracy: 0.7386
# Epoch 58/200
# 804/804 [==============================] - 1s 769us/step - loss: 0.5365 - accuracy: 0.7393
# Epoch 59/200
# 804/804 [==============================] - 1s 778us/step - loss: 0.5374 - accuracy: 0.7382
# Epoch 60/200
# 804/804 [==============================] - 1s 771us/step - loss: 0.5369 - accuracy: 0.7394
# Epoch 61/200
# 804/804 [==============================] - 1s 777us/step - loss: 0.5368 - accuracy: 0.7393
# Epoch 62/200
# 804/804 [==============================] - 1s 767us/step - loss: 0.5367 - accuracy: 0.7395
# Epoch 63/200
# 804/804 [==============================] - 1s 766us/step - loss: 0.5368 - accuracy: 0.7380
# Epoch 64/200
# 804/804 [==============================] - 1s 774us/step - loss: 0.5365 - accuracy: 0.7397
# Epoch 65/200
# 804/804 [==============================] - 1s 768us/step - loss: 0.5364 - accuracy: 0.7389
# Epoch 66/200
# 804/804 [==============================] - 1s 766us/step - loss: 0.5364 - accuracy: 0.7392
# Epoch 67/200
# 804/804 [==============================] - 1s 781us/step - loss: 0.5363 - accuracy: 0.7395
# Epoch 68/200
# 804/804 [==============================] - 1s 773us/step - loss: 0.5364 - accuracy: 0.7386
# Epoch 69/200
# 804/804 [==============================] - 1s 780us/step - loss: 0.5360 - accuracy: 0.7380
# Epoch 70/200
# 804/804 [==============================] - 1s 773us/step - loss: 0.5357 - accuracy: 0.7392
# Epoch 71/200
# 804/804 [==============================] - 1s 773us/step - loss: 0.5360 - accuracy: 0.7381
# Epoch 72/200
# 804/804 [==============================] - 1s 782us/step - loss: 0.5360 - accuracy: 0.7399
# Epoch 73/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 74/200
# 804/804 [==============================] - 1s 773us/step - loss: 0.5358 - accuracy: 0.7387
# Epoch 75/200
# 804/804 [==============================] - 1s 781us/step - loss: 0.5357 - accuracy: 0.7387
# Epoch 76/200
# 804/804 [==============================] - 1s 771us/step - loss: 0.5359 - accuracy: 0.7391
# Epoch 77/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5360 - accuracy: 0.7378
# Epoch 78/200
# 804/804 [==============================] - 1s 766us/step - loss: 0.5354 - accuracy: 0.7393
# Epoch 79/200
# 804/804 [==============================] - 1s 777us/step - loss: 0.5356 - accuracy: 0.7383
# Epoch 80/200
# 804/804 [==============================] - 1s 774us/step - loss: 0.5353 - accuracy: 0.7398
# Epoch 81/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5356 - accuracy: 0.7397
# Epoch 82/200
# 804/804 [==============================] - 1s 777us/step - loss: 0.5351 - accuracy: 0.7393
# Epoch 83/200
# 804/804 [==============================] - 1s 770us/step - loss: 0.5353 - accuracy: 0.7392
# Epoch 84/200
# 804/804 [==============================] - 1s 780us/step - loss: 0.5350 - accuracy: 0.7398
# Epoch 85/200
# 804/804 [==============================] - 1s 774us/step - loss: 0.5355 - accuracy: 0.7390
# Epoch 86/200
# 804/804 [==============================] - 1s 780us/step - loss: 0.5351 - accuracy: 0.7392
# Epoch 87/200
# 804/804 [==============================] - 1s 777us/step - loss: 0.5355 - accuracy: 0.7394
# Epoch 88/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5351 - accuracy: 0.7390
# Epoch 89/200
# 804/804 [==============================] - 1s 781us/step - loss: 0.5349 - accuracy: 0.7401
# Epoch 90/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5351 - accuracy: 0.7400
# Epoch 91/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5350 - accuracy: 0.7389
# Epoch 92/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5346 - accuracy: 0.7404
# Epoch 93/200
# 804/804 [==============================] - 1s 775us/step - loss: 0.5347 - accuracy: 0.7397
# Epoch 94/200
# 804/804 [==============================] - 1s 779us/step - loss: 0.5351 - accuracy: 0.7389
# Epoch 95/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5346 - accuracy: 0.7397
# Epoch 96/200
# 804/804 [==============================] - 1s 776us/step - loss: 0.5347 - accuracy: 0.7399
# Epoch 97/200
# 804/804 [==============================] - 1s 770us/step - loss: 0.5345 - accuracy: 0.7393
# Epoch 98/200
# 804/804 [==============================] - 1s 785us/step - loss: 0.5342 - accuracy: 0.7397
# Epoch 99/200
# 804/804 [==============================] - 1s 771us/step - loss: 0.5345 - accuracy: 0.7399
# Epoch 100/200
# 804/804 [==============================] - 1s 779us/step - loss: 0.5341 - accuracy: 0.7399
# Epoch 101/200
# 804/804 [==============================] - 1s 792us/step - loss: 0.5346 - accuracy: 0.7391
# Epoch 102/200
# 804/804 [==============================] - 1s 796us/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 103/200
# 804/804 [==============================] - 1s 796us/step - loss: 0.5338 - accuracy: 0.7398
# Epoch 104/200
# 804/804 [==============================] - 1s 784us/step - loss: 0.5349 - accuracy: 0.7408
# Epoch 105/200
# 804/804 [==============================] - 1s 811us/step - loss: 0.5345 - accuracy: 0.7398
# Epoch 106/200
# 804/804 [==============================] - 1s 802us/step - loss: 0.5341 - accuracy: 0.7398
# Epoch 107/200
# 804/804 [==============================] - 1s 815us/step - loss: 0.5343 - accuracy: 0.7402
# Epoch 108/200
# 804/804 [==============================] - 1s 809us/step - loss: 0.5343 - accuracy: 0.7399
# Epoch 109/200
# 804/804 [==============================] - 1s 821us/step - loss: 0.5339 - accuracy: 0.7404
# Epoch 110/200
# 804/804 [==============================] - 1s 797us/step - loss: 0.5336 - accuracy: 0.7391
# Epoch 111/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5337 - accuracy: 0.7393
# Epoch 112/200
# 804/804 [==============================] - 1s 794us/step - loss: 0.5337 - accuracy: 0.7395
# Epoch 113/200
# 804/804 [==============================] - 1s 805us/step - loss: 0.5338 - accuracy: 0.7404
# Epoch 114/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5339 - accuracy: 0.7400
# Epoch 115/200
# 804/804 [==============================] - 1s 797us/step - loss: 0.5334 - accuracy: 0.7399
# Epoch 116/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5339 - accuracy: 0.7399
# Epoch 117/200
# 804/804 [==============================] - 1s 790us/step - loss: 0.5337 - accuracy: 0.7401
# Epoch 118/200
# 804/804 [==============================] - 1s 812us/step - loss: 0.5337 - accuracy: 0.7407
# Epoch 119/200
# 804/804 [==============================] - 1s 802us/step - loss: 0.5337 - accuracy: 0.7402
# Epoch 120/200
# 804/804 [==============================] - 1s 797us/step - loss: 0.5332 - accuracy: 0.7407
# Epoch 121/200
# 804/804 [==============================] - 1s 790us/step - loss: 0.5332 - accuracy: 0.7406
# Epoch 122/200
# 804/804 [==============================] - 1s 780us/step - loss: 0.5335 - accuracy: 0.7401
# Epoch 123/200
# 804/804 [==============================] - 1s 811us/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 124/200
# 804/804 [==============================] - 1s 866us/step - loss: 0.5331 - accuracy: 0.7409
# Epoch 125/200
# 804/804 [==============================] - 1s 863us/step - loss: 0.5335 - accuracy: 0.7401
# Epoch 126/200
# 804/804 [==============================] - 1s 853us/step - loss: 0.5338 - accuracy: 0.7402
# Epoch 127/200
# 804/804 [==============================] - 1s 865us/step - loss: 0.5337 - accuracy: 0.7400
# Epoch 128/200
# 804/804 [==============================] - 1s 889us/step - loss: 0.5333 - accuracy: 0.7393
# Epoch 129/200
# 804/804 [==============================] - 1s 864us/step - loss: 0.5330 - accuracy: 0.7403
# Epoch 130/200
# 804/804 [==============================] - 1s 844us/step - loss: 0.5329 - accuracy: 0.7408
# Epoch 131/200
# 804/804 [==============================] - 1s 816us/step - loss: 0.5325 - accuracy: 0.7407
# Epoch 132/200
# 804/804 [==============================] - 1s 833us/step - loss: 0.5333 - accuracy: 0.7405
# Epoch 133/200
# 804/804 [==============================] - 1s 830us/step - loss: 0.5329 - accuracy: 0.7408
# Epoch 134/200
# 804/804 [==============================] - 1s 816us/step - loss: 0.5332 - accuracy: 0.7400
# Epoch 135/200
# 804/804 [==============================] - 1s 822us/step - loss: 0.5330 - accuracy: 0.7406
# Epoch 136/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5327 - accuracy: 0.7408
# Epoch 137/200
# 804/804 [==============================] - 1s 817us/step - loss: 0.5332 - accuracy: 0.7402
# Epoch 138/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5327 - accuracy: 0.7403
# Epoch 139/200
# 804/804 [==============================] - 1s 812us/step - loss: 0.5337 - accuracy: 0.7405
# Epoch 140/200
# 804/804 [==============================] - 1s 809us/step - loss: 0.5330 - accuracy: 0.7400
# Epoch 141/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5328 - accuracy: 0.7414
# Epoch 142/200
# 804/804 [==============================] - 1s 810us/step - loss: 0.5328 - accuracy: 0.7410
# Epoch 143/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5332 - accuracy: 0.7412
# Epoch 144/200
# 804/804 [==============================] - 1s 821us/step - loss: 0.5329 - accuracy: 0.7405
# Epoch 145/200
# 804/804 [==============================] - 1s 818us/step - loss: 0.5331 - accuracy: 0.7405
# Epoch 146/200
# 804/804 [==============================] - 1s 814us/step - loss: 0.5330 - accuracy: 0.7417
# Epoch 147/200
# 804/804 [==============================] - 1s 820us/step - loss: 0.5326 - accuracy: 0.7397
# Epoch 148/200
# 804/804 [==============================] - 1s 816us/step - loss: 0.5326 - accuracy: 0.7410
# Epoch 149/200
# 804/804 [==============================] - 1s 816us/step - loss: 0.5334 - accuracy: 0.7407
# Epoch 150/200
# 804/804 [==============================] - 1s 810us/step - loss: 0.5326 - accuracy: 0.7407
# Epoch 151/200
# 804/804 [==============================] - 1s 828us/step - loss: 0.5321 - accuracy: 0.7415
# Epoch 152/200
# 804/804 [==============================] - 1s 809us/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 153/200
# 804/804 [==============================] - 1s 811us/step - loss: 0.5332 - accuracy: 0.7409
# Epoch 154/200
# 804/804 [==============================] - 1s 809us/step - loss: 0.5322 - accuracy: 0.7409
# Epoch 155/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5323 - accuracy: 0.7406
# Epoch 156/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 157/200
# 804/804 [==============================] - 1s 802us/step - loss: 0.5323 - accuracy: 0.7406
# Epoch 158/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5335 - accuracy: 0.7414
# Epoch 159/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5322 - accuracy: 0.7400
# Epoch 160/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5321 - accuracy: 0.7407
# Epoch 161/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5324 - accuracy: 0.7402
# Epoch 162/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5330 - accuracy: 0.7406
# Epoch 163/200
# 804/804 [==============================] - 1s 817us/step - loss: 0.5328 - accuracy: 0.7405
# Epoch 164/200
# 804/804 [==============================] - 1s 815us/step - loss: 0.5319 - accuracy: 0.7413
# Epoch 165/200
# 804/804 [==============================] - 1s 826us/step - loss: 0.5322 - accuracy: 0.7407
# Epoch 166/200
# 804/804 [==============================] - 1s 823us/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 167/200
# 804/804 [==============================] - 1s 816us/step - loss: 0.5328 - accuracy: 0.7405
# Epoch 168/200
# 804/804 [==============================] - 1s 825us/step - loss: 0.5319 - accuracy: 0.7404
# Epoch 169/200
# 804/804 [==============================] - 1s 811us/step - loss: 0.5326 - accuracy: 0.7407
# Epoch 170/200
# 804/804 [==============================] - 1s 816us/step - loss: 0.5328 - accuracy: 0.7413
# Epoch 171/200
# 804/804 [==============================] - 1s 823us/step - loss: 0.5315 - accuracy: 0.7422
# Epoch 172/200
# 804/804 [==============================] - 1s 816us/step - loss: 0.5322 - accuracy: 0.7413
# Epoch 173/200
# 804/804 [==============================] - 1s 812us/step - loss: 0.5321 - accuracy: 0.7409
# Epoch 174/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5317 - accuracy: 0.7413
# Epoch 175/200
# 804/804 [==============================] - 1s 811us/step - loss: 0.5321 - accuracy: 0.7410
# Epoch 176/200
# 804/804 [==============================] - 1s 801us/step - loss: 0.5319 - accuracy: 0.7410
# Epoch 177/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5343 - accuracy: 0.7420
# Epoch 178/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 179/200
# 804/804 [==============================] - 1s 802us/step - loss: 0.5317 - accuracy: 0.7416
# Epoch 180/200
# 804/804 [==============================] - 1s 817us/step - loss: 0.5329 - accuracy: 0.7404
# Epoch 181/200
# 804/804 [==============================] - 1s 802us/step - loss: 0.5317 - accuracy: 0.7403
# Epoch 182/200
# 804/804 [==============================] - 1s 800us/step - loss: 0.5312 - accuracy: 0.7416
# Epoch 183/200
# 804/804 [==============================] - 1s 809us/step - loss: 0.5319 - accuracy: 0.7406
# Epoch 184/200
# 804/804 [==============================] - 1s 797us/step - loss: 0.5318 - accuracy: 0.7406
# Epoch 185/200
# 804/804 [==============================] - 1s 810us/step - loss: 0.5330 - accuracy: 0.7411
# Epoch 186/200
# 804/804 [==============================] - 1s 801us/step - loss: 0.5325 - accuracy: 0.7404
# Epoch 187/200
# 804/804 [==============================] - 1s 800us/step - loss: 0.5318 - accuracy: 0.7414
# Epoch 188/200
# 804/804 [==============================] - 1s 797us/step - loss: 0.5316 - accuracy: 0.7409
# Epoch 189/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5323 - accuracy: 0.7402
# Epoch 190/200
# 804/804 [==============================] - 1s 794us/step - loss: 0.5316 - accuracy: 0.7413
# Epoch 191/200
# 804/804 [==============================] - 1s 809us/step - loss: 0.5318 - accuracy: 0.7413
# Epoch 192/200
# 804/804 [==============================] - 1s 797us/step - loss: 0.5321 - accuracy: 0.7411
# Epoch 193/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5316 - accuracy: 0.7414
# Epoch 194/200
# 804/804 [==============================] - 1s 804us/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 195/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5317 - accuracy: 0.7409
# Epoch 196/200
# 804/804 [==============================] - 1s 807us/step - loss: 0.5316 - accuracy: 0.7414
# Epoch 197/200
# 804/804 [==============================] - 1s 795us/step - loss: 0.5315 - accuracy: 0.7411
# Epoch 198/200
# 804/804 [==============================] - 1s 806us/step - loss: 0.5313 - accuracy: 0.7411
# Epoch 199/200
# 804/804 [==============================] - 1s 801us/step - loss: 0.5316 - accuracy: 0.7408
# Epoch 200/200
# 804/804 [==============================] - 1s 812us/step - loss: 0.5316 - accuracy: 0.7417

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5736 - accuracy: 0.7279 - 286ms/epoch - 1ms/step
# Loss: 0.5735864043235779, Accuracy: 0.7279300093650818

# %%
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh','sigmoid'])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=20), activation=activation, input_dim=43))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=100,
            step=20),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=100,
    hyperband_iterations=10)
# Out:
# Reloading Tuner from .\untitled_project\tuner0.json

# %%
tuner.search(X_train_scaled,y_train,epochs=40,validation_data=(X_test_scaled,y_test))
# Out:
# Trial 496 Complete [00h 01m 36s]
# val_accuracy: 0.7317784428596497
#
# Best val_accuracy So Far: 0.7338775396347046
# Total elapsed time: 01h 38m 12s
#
# Search: Running Trial #497
#
# Value             |Best Value So Far |Hyperparameter
# relu              |sigmoid           |activation
# 5                 |7                 |first_units
# 6                 |6                 |num_layers
# 9                 |7                 |units_0
# 5                 |7                 |units_1
# 7                 |1                 |units_2
# 9                 |7                 |units_3
# 7                 |7                 |units_4
# 9                 |9                 |units_5
# 100               |12                |tuner/epochs
# 0                 |4                 |tuner/initial_epoch
# 0                 |4                 |tuner/bracket
# 0                 |2                 |tuner/round
#
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6417 - accuracy: 0.6790 - val_loss: 0.5946 - val_accuracy: 0.7186
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5837 - accuracy: 0.7236 - val_loss: 0.5753 - val_accuracy: 0.7250
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5728 - accuracy: 0.7267 - val_loss: 0.5726 - val_accuracy: 0.7244
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5689 - accuracy: 0.7286 - val_loss: 0.5713 - val_accuracy: 0.7255
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5660 - accuracy: 0.7303 - val_loss: 0.5714 - val_accuracy: 0.7283
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5626 - accuracy: 0.7292 - val_loss: 0.5674 - val_accuracy: 0.7245
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5618 - accuracy: 0.7294 - val_loss: 0.5683 - val_accuracy: 0.7210
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5610 - accuracy: 0.7302 - val_loss: 0.5654 - val_accuracy: 0.7250
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5607 - accuracy: 0.7309 - val_loss: 0.5655 - val_accuracy: 0.7282
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5599 - accuracy: 0.7312 - val_loss: 0.5645 - val_accuracy: 0.7257
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5586 - accuracy: 0.7311 - val_loss: 0.5653 - val_accuracy: 0.7266
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5582 - accuracy: 0.7311 - val_loss: 0.5622 - val_accuracy: 0.7284
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5574 - accuracy: 0.7303 - val_loss: 0.5629 - val_accuracy: 0.7270
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5571 - accuracy: 0.7313 - val_loss: 0.5635 - val_accuracy: 0.7270
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5567 - accuracy: 0.7294 - val_loss: 0.5638 - val_accuracy: 0.7256
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5559 - accuracy: 0.7304 - val_loss: 0.5640 - val_accuracy: 0.7264
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5555 - accuracy: 0.7309 - val_loss: 0.5598 - val_accuracy: 0.7263
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5547 - accuracy: 0.7318 - val_loss: 0.5625 - val_accuracy: 0.7286
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5554 - accuracy: 0.7311 - val_loss: 0.5615 - val_accuracy: 0.7276
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5542 - accuracy: 0.7320 - val_loss: 0.5614 - val_accuracy: 0.7236
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5548 - accuracy: 0.7311 - val_loss: 0.5582 - val_accuracy: 0.7284
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5537 - accuracy: 0.7327 - val_loss: 0.5591 - val_accuracy: 0.7234
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5536 - accuracy: 0.7315 - val_loss: 0.5597 - val_accuracy: 0.7283
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5528 - accuracy: 0.7317 - val_loss: 0.5577 - val_accuracy: 0.7254
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5530 - accuracy: 0.7325 - val_loss: 0.5604 - val_accuracy: 0.7293
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5527 - accuracy: 0.7311 - val_loss: 0.5594 - val_accuracy: 0.7287
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5525 - accuracy: 0.7323 - val_loss: 0.5571 - val_accuracy: 0.7259
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7329 - val_loss: 0.5571 - val_accuracy: 0.7298
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5524 - accuracy: 0.7313 - val_loss: 0.5601 - val_accuracy: 0.7272
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5530 - accuracy: 0.7334 - val_loss: 0.5600 - val_accuracy: 0.7268
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5523 - accuracy: 0.7328 - val_loss: 0.5602 - val_accuracy: 0.7278
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5518 - accuracy: 0.7330 - val_loss: 0.5591 - val_accuracy: 0.7248
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7336 - val_loss: 0.5579 - val_accuracy: 0.7292
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5512 - accuracy: 0.7326 - val_loss: 0.5584 - val_accuracy: 0.7282
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5516 - accuracy: 0.7339 - val_loss: 0.5590 - val_accuracy: 0.7220
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5511 - accuracy: 0.7338 - val_loss: 0.5572 - val_accuracy: 0.7273
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5507 - accuracy: 0.7330 - val_loss: 0.5576 - val_accuracy: 0.7284
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5508 - accuracy: 0.7328 - val_loss: 0.5583 - val_accuracy: 0.7234
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5519 - accuracy: 0.7333 - val_loss: 0.5591 - val_accuracy: 0.7269
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5525 - accuracy: 0.7336 - val_loss: 0.5621 - val_accuracy: 0.7278
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5529 - accuracy: 0.7342 - val_loss: 0.5591 - val_accuracy: 0.7290
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5518 - accuracy: 0.7330 - val_loss: 0.5584 - val_accuracy: 0.7240
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5510 - accuracy: 0.7343 - val_loss: 0.5590 - val_accuracy: 0.7256
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5505 - accuracy: 0.7331 - val_loss: 0.5591 - val_accuracy: 0.7273
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5509 - accuracy: 0.7332 - val_loss: 0.5587 - val_accuracy: 0.7272
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5504 - accuracy: 0.7343 - val_loss: 0.5591 - val_accuracy: 0.7256
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7341 - val_loss: 0.5584 - val_accuracy: 0.7292
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5500 - accuracy: 0.7345 - val_loss: 0.5570 - val_accuracy: 0.7265
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7329 - val_loss: 0.5584 - val_accuracy: 0.7289
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7338 - val_loss: 0.5572 - val_accuracy: 0.7286
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5498 - accuracy: 0.7337 - val_loss: 0.5572 - val_accuracy: 0.7293
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7337 - val_loss: 0.5572 - val_accuracy: 0.7271
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5495 - accuracy: 0.7342 - val_loss: 0.5583 - val_accuracy: 0.7296
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.7326 - val_loss: 0.5590 - val_accuracy: 0.7247
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5489 - accuracy: 0.7338 - val_loss: 0.5587 - val_accuracy: 0.7278
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5492 - accuracy: 0.7339 - val_loss: 0.5598 - val_accuracy: 0.7273
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7331 - val_loss: 0.5588 - val_accuracy: 0.7257
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5496 - accuracy: 0.7329 - val_loss: 0.5571 - val_accuracy: 0.7287
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5488 - accuracy: 0.7345 - val_loss: 0.5569 - val_accuracy: 0.7277
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5490 - accuracy: 0.7338 - val_loss: 0.5594 - val_accuracy: 0.7287
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5492 - accuracy: 0.7339 - val_loss: 0.5578 - val_accuracy: 0.7277
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7352 - val_loss: 0.5595 - val_accuracy: 0.7279
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7341 - val_loss: 0.5572 - val_accuracy: 0.7284
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5487 - accuracy: 0.7332 - val_loss: 0.5578 - val_accuracy: 0.7289
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5488 - accuracy: 0.7331 - val_loss: 0.5577 - val_accuracy: 0.7283
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5492 - accuracy: 0.7337 - val_loss: 0.5585 - val_accuracy: 0.7289
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5479 - accuracy: 0.7348 - val_loss: 0.5579 - val_accuracy: 0.7279
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5483 - accuracy: 0.7337 - val_loss: 0.5582 - val_accuracy: 0.7296
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5483 - accuracy: 0.7349 - val_loss: 0.5600 - val_accuracy: 0.7284
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5485 - accuracy: 0.7352 - val_loss: 0.5579 - val_accuracy: 0.7299
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5487 - accuracy: 0.7343 - val_loss: 0.5582 - val_accuracy: 0.7275
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5483 - accuracy: 0.7336 - val_loss: 0.5586 - val_accuracy: 0.7304
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5487 - accuracy: 0.7338 - val_loss: 0.5577 - val_accuracy: 0.7278
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5488 - accuracy: 0.7341 - val_loss: 0.5570 - val_accuracy: 0.7294
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5482 - accuracy: 0.7337 - val_loss: 0.5569 - val_accuracy: 0.7250
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7344 - val_loss: 0.5606 - val_accuracy: 0.7291
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7340 - val_loss: 0.5589 - val_accuracy: 0.7306
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5477 - accuracy: 0.7355 - val_loss: 0.5586 - val_accuracy: 0.7266
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7355 - val_loss: 0.5581 - val_accuracy: 0.7282
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7342 - val_loss: 0.5589 - val_accuracy: 0.7254
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5483 - accuracy: 0.7345 - val_loss: 0.5579 - val_accuracy: 0.7248
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7346 - val_loss: 0.5591 - val_accuracy: 0.7276
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5479 - accuracy: 0.7342 - val_loss: 0.5587 - val_accuracy: 0.7296
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5476 - accuracy: 0.7349 - val_loss: 0.5570 - val_accuracy: 0.7305
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5474 - accuracy: 0.7352 - val_loss: 0.5602 - val_accuracy: 0.7242
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5480 - accuracy: 0.7361 - val_loss: 0.5579 - val_accuracy: 0.7299
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7345 - val_loss: 0.5582 - val_accuracy: 0.7263
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5479 - accuracy: 0.7343 - val_loss: 0.5572 - val_accuracy: 0.7290
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7340 - val_loss: 0.5583 - val_accuracy: 0.7287
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7358 - val_loss: 0.5586 - val_accuracy: 0.7262
# Epoch 91/100
# 209/804 [======>.......................] - ETA: 0s - loss: 0.5406 - accuracy: 0.7404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Bootcamp\Github\deep-learning-challenge\Starter_Code.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Bootcamp/Github/deep-learning-challenge/Starter_Code.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> tuner.search(X_train_scaled,y_train,epochs=40,validation_data=(X_test_scaled,y_test))
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\base_tuner.py:233, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     230         continue
#     232     self.on_trial_begin(trial)
# --> 233     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     234     self.on_trial_end(trial)
#     235 self.on_search_end()
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\base_tuner.py:273, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     271 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     272     try:
# --> 273         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     274         trial.status = trial_module.TrialStatus.COMPLETED
#     275         return
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\base_tuner.py:238, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     237 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 238     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     239     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     240         self.oracle.objective.name
#     241     ):
#     242         # The oracle is updated by calling `self.oracle.update_trial()` in
#     243         # `Tuner.run_trial()`. For backward compatibility, we support this
#     244         # use case. No further action needed in this case.
#     245         warnings.warn(
#     246             "The use case of calling "
#     247             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     253             stacklevel=2,
#     254         )
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras_tuner\src\tuners\hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\engine\training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File e:\ProgramData\anaconda3\envs\dev\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
best_hyper = tuner.get_best_hyperparameters(1)[0]
best_hyper.values
# Out:
# {'activation': 'sigmoid',
#  'first_units': 7,
#  'num_layers': 6,
#  'units_0': 7,
#  'units_1': 7,
#  'units_2': 1,
#  'units_3': 7,
#  'units_4': 7,
#  'units_5': 9,
#  'tuner/epochs': 12,
#  'tuner/initial_epoch': 4,
#  'tuner/bracket': 4,
#  'tuner/round': 2,
#  'tuner/trial_id': '0352'}

# %%
best_model = tuner.get_best_models(1)[0]
model_loss, model_accuracy = best_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5761 - accuracy: 0.7339 - 351ms/epoch - 1ms/step
# Loss: 0.5761455297470093, Accuracy: 0.7338775396347046

# %%
# Export our model to HDF5 file
nn.save('my_model.h5')
# Out:
# e:\ProgramData\anaconda3\envs\dev\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
